# %%
from imageai.Detection import ObjectDetection, VideoObjectDetection
import os

# %%
model_path = "C:/Users/navid.hejazi/OneDrive - Tensator/Desktop/YOLO/Models"
images_path = "C:/Users/navid.hejazi/OneDrive - Tensator/Desktop/YOLO/Images"
video_path = "C:/Users/navid.hejazi/OneDrive - Tensator/Desktop/YOLO/Videos"

# %%
detector = ObjectDetection()

# %%
detector.setModelTypeAsYOLOv3()

# %%
detector.setModelPath(os.path.join(model_path , "yolov3.pt"))

# %%
detector.loadModel()

# %%
detection = detector.detectObjectsFromImage(input_image=os.path.join(images_path, "05_tehran.jpg"), output_image_path = os.path.join(images_path, "05_tehran_detected.jpg"))

# %%
detection
# Out:
# [{'name': 'person',
#   'percentage_probability': 88.48,
#   'box_points': [71, 216, 80, 234]},
#  {'name': 'person',
#   'percentage_probability': 83.67,
#   'box_points': [300, 215, 309, 230]},
#  {'name': 'person',
#   'percentage_probability': 94.8,
#   'box_points': [272, 206, 280, 223]},
#  {'name': 'car',
#   'percentage_probability': 99.59,
#   'box_points': [71, 232, 102, 257]},
#  {'name': 'car',
#   'percentage_probability': 97.95,
#   'box_points': [429, 267, 479, 300]},
#  {'name': 'car',
#   'percentage_probability': 99.76,
#   'box_points': [123, 231, 152, 255]},
#  {'name': 'car',
#   'percentage_probability': 99.23,
#   'box_points': [327, 260, 372, 295]},
#  {'name': 'car',
#   'percentage_probability': 96.5,
#   'box_points': [322, 239, 357, 263]},
#  {'name': 'car',
#   'percentage_probability': 99.42,
#   'box_points': [264, 229, 292, 255]},
#  {'name': 'car',
#   'percentage_probability': 97.38,
#   'box_points': [349, 222, 385, 250]},
#  {'name': 'car',
# ...

# %%
custom_detector = detector.CustomObjects(traffic_light=True)

# %%
custom_detection = detector.detectObjectsFromImage(custom_objects= custom_detector,input_image=os.path.join(images_path, "04_tehran.png"), output_image_path = os.path.join(images_path, "04_tehran_customdetected.jpg"), minimum_percentage_probability=80)

# %%
custom_detection
# Out:
# [{'name': 'traffic light',
#   'percentage_probability': 99.98,
#   'box_points': [1775, 202, 1854, 368]},
#  {'name': 'traffic light',
#   'percentage_probability': 99.99,
#   'box_points': [316, 86, 398, 294]},
#  {'name': 'traffic light',
#   'percentage_probability': 99.99,
#   'box_points': [259, 250, 315, 376]}]

# %%
# Video object detection

# %%
video_detector = VideoObjectDetection()

# %%
video_detector.setModelTypeAsYOLOv3()

# %%
video_detector.setModelPath(os.path.join(model_path , "yolov3.pt"))
video_detector.loadModel()

# %%
vid_detection = video_detector.detectObjectsFromVideo(input_file_path= os.path.join(video_path, "driving_camera.mp4"), output_file_path= os.path.join(video_path, "driving_camera_det"), frames_per_second=30, log_progress=True)
# Out:
# Processing Frame :  1
# Processing Frame :  2
# Processing Frame :  3
# Processing Frame :  4
# Processing Frame :  5
# Processing Frame :  6
# Processing Frame :  7
# Processing Frame :  8
# Processing Frame :  9
# Processing Frame :  10
# Processing Frame :  11
# Processing Frame :  12
# Processing Frame :  13
# Processing Frame :  14
# Processing Frame :  15
# Processing Frame :  16
# Processing Frame :  17
# Processing Frame :  18
# Processing Frame :  19
# Processing Frame :  20
# Processing Frame :  21
# Processing Frame :  22
# Processing Frame :  23
# Processing Frame :  24
# Processing Frame :  25
# Processing Frame :  26
# Processing Frame :  27
# Processing Frame :  28
# Processing Frame :  29
# Processing Frame :  30
# Processing Frame :  31
# Processing Frame :  32
# Processing Frame :  33
# Processing Frame :  34
# Processing Frame :  35
# Processing Frame :  36
# Processing Frame :  37
# Processing Frame :  38
# Processing Frame :  39
# Processing Frame :  40
# ...

# %%
video_detector.setModelPath(os.path.join(model_path , "yolov3.h5"))
video_detector.loadModel()
vid_detection = video_detector.detectObjectsFromVideo(input_file_path= os.path.join(video_path, "street_camera.mp4"), output_file_path= os.path.join(video_path, "street_camera_det"), frames_per_second=20, log_progress=True)
# Out:
# Processing Frame :  1
# Processing Frame :  2
# Processing Frame :  3
# Processing Frame :  4
# Processing Frame :  5
# Processing Frame :  6
# Processing Frame :  7
# Processing Frame :  8
# Processing Frame :  9
# Processing Frame :  10
# Processing Frame :  11
# Processing Frame :  12
# Processing Frame :  13
# Processing Frame :  14
# Processing Frame :  15
# Processing Frame :  16
# Processing Frame :  17
# Processing Frame :  18
# Processing Frame :  19
# Processing Frame :  20
# Processing Frame :  21

# %%
video_detector.setModelPath(os.path.join(model_path , "yolov3.h5"))
video_detector.loadModel(detection_speed="fast")
vid_detection = video_detector.detectObjectsFromVideo(input_file_path= os.path.join(video_path, "street_camera.mp4"), output_file_path= os.path.join(video_path, "street_camera_fast_det"), frames_per_second=20, log_progress=True)

# %%
video_detector.setModelPath(os.path.join(model_path , "yolov3.h5"))
video_detector.loadModel(detection_speed="faster")
vid_detection = video_detector.detectObjectsFromVideo(input_file_path= os.path.join(video_path, "street_camera.mp4"), output_file_path= os.path.join(video_path, "street_camera_faster_det"), frames_per_second=20, log_progress=True)

# %%
video_detector.setModelPath(os.path.join(model_path , "yolov3.h5"))
video_detector.loadModel(detection_speed="flash")
vid_detection = video_detector.detectObjectsFromVideo(input_file_path= os.path.join(video_path, "street_camera.mp4"), output_file_path= os.path.join(video_path, "street_camera_flash_det"), frames_per_second=20, log_progress=True)

# %%
# Using the Webcam
import cv2 as cv

# %%
camera = cv.VideoCapture(0)

# %%
webcam_detector = VideoObjectDetection()
webcam_detector.setModelTypeAsYOLOv3()
webcam_detector.setModelPath(os.path.join(model_path , "yolov3.h5"))
webcam_detector.loadModel()

# %%
vid_detection = video_detector.detectObjectsFromVideo(camera_input=camera, output_file_path = os.path.join(video_path, "camera_detected_video"),
                frames_per_second = 20, log_progress=True)
# Out:
# Processing Frame :  1
# Processing Frame :  2
# Processing Frame :  3
# Processing Frame :  4
# Processing Frame :  5
# Processing Frame :  6
# Processing Frame :  7
# Processing Frame :  8
# Processing Frame :  9
# Processing Frame :  10
# Processing Frame :  11
# Processing Frame :  12
# Processing Frame :  13
# Processing Frame :  14
# Processing Frame :  15
# Processing Frame :  16
# Processing Frame :  17
# Processing Frame :  18
# Processing Frame :  19
# Processing Frame :  20
# Processing Frame :  21
# Processing Frame :  22
# Processing Frame :  23
# Processing Frame :  24
# Processing Frame :  25
# Processing Frame :  26
# Processing Frame :  27
# Processing Frame :  28
# Processing Frame :  29
# Processing Frame :  30
# Processing Frame :  31
# Processing Frame :  32
# Processing Frame :  33
# Processing Frame :  34
# Processing Frame :  35
# Processing Frame :  36
# Processing Frame :  37
# Processing Frame :  38
# Processing Frame :  39
# Processing Frame :  40
# ...
